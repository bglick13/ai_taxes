# %%
import sys, os
if '..' not in sys.path:
    sys.path.append('..')
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ben\\Documents\\ai_taxes\\notebooks'

# %%
with open('../experiments/malthusian_open_borders/logs/dense_log.pickle', 'rb') as f:
    logs = pickle.load(f)
    
with open('../experiments/malthusian_open_borders/logs/skills.pickle', 'rb') as f:
    skills = pickle.load(f)

# %%
logs.keys()
# Out:
# dict_keys(['world', 'states', 'actions', 'rewards', 'Build', 'Trade', 'Gather', 'Citizenship', 'PeriodicTax'])

# %%
logs['Citizenship']
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'bar_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'bar_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}],
#   [{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}],
#   [{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}],
#   [{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}],
#   [{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}],
#   [{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}],
#   [{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 3, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 0, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 1, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 2, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [[{'agent_idx': 4, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[{'agent_idx': 5, 'from_nation': 'foo_land', 'to_nation': 'foo_land'}]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
planner_rewards = pd.DataFrame([r['p'] for r in logs['rewards']])

# %%
planner_rewards.cumsum().plot()

# %%
agent_rewards = pd.DataFrame(logs['rewards']).drop('p', 1)

# %%
agent_rewards.cumsum().plot()
